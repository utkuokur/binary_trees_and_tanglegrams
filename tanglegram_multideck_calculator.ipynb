# %%
import itertools
from collections import defaultdict
import numpy as np

WE = defaultdict(lambda: None)
WE[0] = 0 
WE[1] = 1

#outputs the Wedderburn number for n
def W(n):
    if n == 0:
        return 0
    if n == 1:
        return 1
    if WE[n] == None: 
        if n % 2 == 1:
            s = sum([W(i) * W(n-i) for i in range(1, (n+1)//2)])
            WE[n] = s
        else:
            s = sum([W(i) * W(n-i) for i in range(1, n//2)])
            s += (W(n//2) * (W(n/2) + 1)) / 2  #W(n/2) choose 2 + W(n/2)
            WE[n] = s
    return WE[n]

#in: L list, unordered with duplicates
#out: ordered list L without duplicates
def Oset(L):
    return sorted(list(dict.fromkeys(L)))

#inputs two list of pairs of integers lst1 and lst2 
#outputs a list of ordered pairs ((x,y),(z,w)) 
#such that (x,y) <= (z,w), and (x,y) in lst1 and (z,w) in lst2 or vice versa
def unordered_pairs(lst1, lst2):
    if len(lst1) == 0 or len(lst1) == 0:
        return []
    else: 
        L = [(y, x) if x <= y else (x, y) for x, y in set(itertools.product(lst1, lst2))]
        return Oset(L)

#inputs tree_0 = (n_0,s_0) and tree_1 = (n_1,s_1)
#outputs tree = (n,s) such that tree is tree_0 \oplus tree_1
def binary_tree(tree_0,tree_1):
    ((n_0,s_0),(n_1,s_1)) = sorted((tree_0,tree_1))
    if n_0 == 0: 
        return (n_1,s_1)
    if n_1 == 0: 
        return (n_0,s_0)
    n = n_0 + n_1
    if n_0 == n_1:
        y = W(n_0)
        s = sum([ W(n - i) * W(i) for i in range(1,n_0)]) + sum([ y-i for i in range(s_0)]) + s_1 - s_0
    else: 
        s = sum([ W(n - i) * W(i) for i in range(1,n_0)]) +  W(n_0) * s_1 + s_0
    return (n,s)

# input: pairs of integers (n,t)
# output: the root split of s'th binary tree (in lex order) on n leaves in the form ((n_0,s_0),(n_1,s_1))
def root_split_finder(pair):
    n=pair[0]
    t = pair[1]
    if t >= W(n):
        raise ValueError("there is no tree for t = ",t)
    if n == 1:
        return ((1,0),(0,0))
    elif n % 2 == 1:
        i = 1
        while W(n-i) * W(i) <= t: 
            t-=W(n-i) * W(i)
            i += 1
        (s_1,s_2) = divmod(int(t),int(W(i)))
        return ((n-i,s_1),(i,s_2))
    else:
        i = 1
        while i <= n/2 and W(n-i) * W(i) <= t: 
            t-=W(n-i) * W(i)
            i+=1      
        (s_1,s_2) = divmod(int(t),int(W(i)))
        if i != n/2:
            return ((n-i,s_1),(i,s_2))
        else:
            y = W(n//2)
            j = 0
            r = 0
            while y-j-1 < t:
                t -= (y-j)
                j += 1
                r += 1
            return ((n//2,t+r),(n//2,j))     

m=defaultdict(lambda: defaultdict(lambda: None ))

#in: a binary tree in the form pair = (n,s)  
#out: draws it in ascii_art  (using the BinaryTree class of Sagemath)
def draw(pair):
    def convert_back(pair):
        T_1 = BinaryTree([])
        (n,s) = (pair[0],pair[1])
        if n == 1:
            return T_1
        if n > 1:
            pair = root_split_finder((n,s))
            T_left = convert_back(pair[0])
            T_right = convert_back(pair[1])
            return BinaryTree([T_left,T_right])
    print(ascii_art(convert_back(pair)))    


#in: permutation and dictionary of left and right buttons in the form {0: [], 1:[]}
#out: pressed permutation
def press_buttons(p,dct):
    
    #in: permutation and list of left buttons
    def press_left_buttons(p,buttons):
        if not buttons:
            return p
        else:
            button = buttons[0]
            if not button:
                return p
            else:
                midpoint = mid(button)
                q = Permutation(p[ : button[0]-1] + p[ midpoint  : button[1] ]+p[ button[0]-1 : midpoint] + p[ button[1] : ])
                return press_left_buttons(q,buttons[1:])
            
    #in: permutation and list of left buttons
    def press_right_buttons(p,buttons):
        if not buttons:
            return p
        else:
            button = buttons[0]
            if not button:
                return p
            else:
                q = p.inverse()
                midpoint = mid(button)
                q_pressed = Permutation(q[ : button[0]-1] + q[ midpoint  : button[1] ]+q[ button[0]-1 : midpoint] + q[ button[1] : ])
                return press_right_buttons(q_pressed.inverse(),buttons[1:])
            
    q = press_left_buttons(p,dct[0])
    return press_right_buttons(q,dct[1])


#in: permutation p and a button as a pair
#out: 
def mid(button):
    (a,b) = (button[0],button[1])
    if a == b:
        return a-1
    else:
        return (a + b -1)//2

#in: button
#out: length of button
def length_of(button):
    return (button[1] - button[0] + 1)/2

#in: a pattern pat on the elements 1,...,i-1,i+1,...,n
#out: the permutation p on the elements 1,...,n-1
def perm_canonicalizer(pat, i):
    # Standardize to 1..len(pat) by relative order
    sorted_vals = sorted(set(pat))
    rank = {v: k+1 for k, v in enumerate(sorted_vals)}
    return Permutation([rank[x] for x in pat])

#in: a pattern pat on the elements 1,...,i-1,i+1,...,n
#out: the permutation p on the elements 1,...,n-1
# def perm_canonicalizer(pat,i):
#     return  Permutation([x+1 if x<i else x for x in pat]  )

m=defaultdict(lambda: defaultdict(lambda: None ))

def sorted_matrix(M):
    return sorted([sorted(row) for row in M ] ) 


def tangle_into_double_rooted_graph(T_1):
    """
    Convert a tanglegram into a triple (Graph, left_root, right_root).
    
    A tanglegram T_1 = ((n, bl), (n, br), perm) consists of:
      - Left binary tree with n leaves (indexed by bl in Wedderburn-Etherington order)
      - Right binary tree with n leaves (indexed by br)
      - A permutation matching leaves of left tree to leaves of right tree
    
    The output is a triple (G, left_root, right_root) where:
      - G is a Sage Graph containing both tree structures plus matching edges
      - left_root is the vertex ID of the left tree's root
      - right_root is the vertex ID of the right tree's root
    
    Two tanglegrams are isomorphic iff there exists a graph isomorphism
    mapping left_root to left_root and right_root to right_root.
    """
    (ltree_pair, rtree_pair, perm) = T_1
    
    def convert_back(pair):
        T = BinaryTree([])
        (n, s) = (pair[0], pair[1])
        if n == 1:
            return T
        if n > 1:
            pair = root_split_finder((n, s))
            T_left = convert_back(pair[0])
            T_right = convert_back(pair[1])
            return BinaryTree([T_left, T_right])
    
    G = Graph()
    
    # --- Build left tree ---
    left_leaf_vertices = []
    
    def build_left(tree):
        v = G.order()
        G.add_vertex(v)
        if tree == BinaryTree([]):
            left_leaf_vertices.append(v)
            return v
        left_v = build_left(tree[0])
        right_v = build_left(tree[1])
        G.add_edge(v, left_v)
        G.add_edge(v, right_v)
        return v
    
    left_root = build_left(convert_back(ltree_pair))
    n = len(left_leaf_vertices)
    
    # --- Build right tree ---
    right_leaf_vertices = []
    
    def build_right(tree):
        v = G.order()
        G.add_vertex(v)
        if tree == BinaryTree([]):
            right_leaf_vertices.append(v)
            return v
        left_v = build_right(tree[0])
        right_v = build_right(tree[1])
        G.add_edge(v, left_v)
        G.add_edge(v, right_v)
        return v
    
    right_root = build_right(convert_back(rtree_pair))
    
    # --- Add matching edges according to permutation ---
    p = Permutation(perm)
    for i in range(n):
        G.add_edge(left_leaf_vertices[i], right_leaf_vertices[p[i] - 1])
    
    return (G, left_root, right_root)

is_isomorphic_cache = {}

def is_isomorphic(T_1, T_2):
    """
    Test whether two tanglegrams are isomorphic.

    Tanglegrams T_1 = (L_1, R_1, perm_1) and T_2 = (L_2, R_2, perm_2) are
    isomorphic iff:
      1. The left trees are the same shape: L_1 == L_2
      2. The right trees are the same shape: R_1 == R_2
      3. There exists a graph automorphism of the combined structure that
         maps left root to left root, right root to right root, and
         respects the matching edges.

    We test condition 3 using Sage's canonical_label() with a partition
    that separates the two roots into distinct singleton classes.  If the
    canonical forms of both graphs (under these constrained partitions)
    are equal, then a root-preserving isomorphism exists.

    This avoids the problem with certificate-based checking where Sage
    returns only one of potentially many isomorphisms, which might swap
    the two roots.
    """
    # Check tree shapes match (WE indices uniquely identify non-isomorphic trees)
    if T_1[0] != T_2[0] or T_1[1] != T_2[1]:
        return False

    # Quick positive check: identical permutations
    if T_1[2] == T_2[2]:
        return True

    # Build graph triples for both tanglegrams
    (G1, left_root_1, right_root_1) = tangle_into_double_rooted_graph(T_1)
    (G2, left_root_2, right_root_2) = tangle_into_double_rooted_graph(T_2)

    # Build partitions that force roots to map to corresponding roots.
    # Each root is in its own singleton class; all other vertices share a class.
    other_1 = [v for v in G1.vertices() if v not in [left_root_1, right_root_1]]
    other_2 = [v for v in G2.vertices() if v not in [left_root_2, right_root_2]]

    # canonical_label with partition constrains the canonization so that
    # only isomorphisms respecting the partition are considered.  By putting
    # each root in its own singleton class, we force:
    #   left_root_1  -> left_root_2
    #   right_root_1 -> right_root_2
    # The canonical forms are equal iff such a root-preserving iso exists.
    return (
        G1.canonical_label(partition=[[left_root_1], [right_root_1], other_1])
        ==
        G2.canonical_label(partition=[[left_root_2], [right_root_2], other_2]) )


def memoized_is_isomorphic(T1, T2):
    try:
        key = tuple(sorted((T1, T2)))
    except TypeError:
        key = frozenset(map(str, (T1, T2)))
    if key in is_isomorphic_cache:
        return is_isomorphic_cache[key]
    result = is_isomorphic(T1, T2)
    is_isomorphic_cache[key] = result
    return result
    
def generate_list_of_representatives(n):
    representatives = []
    k = W(n)
    
    for bl in range(k):
        for br in range(k):
            for perm in Permutations(n):
                tan = ((n, bl), (n, br), perm)
                is_new_class = True
                for rep in representatives:
                    if memoized_is_isomorphic(tan, rep):
                        is_new_class = False
                        break
                if is_new_class:
                    representatives.append(tan)
                    
    return representatives

def tan_multideck(tan):

    cbus = defaultdict(lambda: {0: [], 1:[]})

    def card_finder_with_left_buttons(pair, tup, j):
        n = pair[0]
        s = pair[1]
        k = len(tup)
        if k == 0: 
            card = (0,0)
        if k == n:
            card = pair
        if n > k > 0:
            root_split = root_split_finder(pair)
            left_tree = root_split[0]
            right_tree = root_split[1]
            left_sublist = tuple([ i for i in tup if i < left_tree[0] ])
            right_sublist = tuple([ i for i in tup if left_tree[0] <= i])
            right_sublist_adjusted = tuple([ i - left_tree[0] for i in right_sublist])
            left_card = card_finder_with_left_buttons( left_tree, left_sublist, j)
            right_card = card_finder_with_left_buttons( right_tree, right_sublist_adjusted, j)
            card = binary_tree(left_card,right_card)
            if left_card < right_card and 1 < left_tree[0] and k > 2:
                tup_canon = perm_canonicalizer(tup,j)
                cbutton = (tup_canon[0],tup_canon[-1])
                cbus[j][0].append(cbutton)
        return card

    def card_finder_with_right_buttons(pair, tup, j, p):
        n = pair[0]
        s = pair[1]
        k = len(tup)
        if k == 0:
            card = (0,0)
        if k == n:
            card = pair
        if n > k > 0:
            root_split = root_split_finder(pair)
            left_tree = root_split[0]
            right_tree = root_split[1]
            left_sublist = tuple([ i for i in tup if i < left_tree[0] ])
            right_sublist = tuple([ i for i in tup if left_tree[0] <= i])
            right_sublist_adjusted = tuple([ i - left_tree[0] for i in right_sublist])
            left_card = card_finder_with_right_buttons( left_tree, left_sublist, j, p)
            right_card = card_finder_with_right_buttons( right_tree, right_sublist_adjusted, j, p)
            card = binary_tree(left_card,right_card)
            if left_card < right_card and 1 < left_tree[0] and k > 2:
                tup_canon = perm_canonicalizer(tup,j)
                cbutton = (tup_canon[0],tup_canon[-1])
                a = p[j-1]
                cbus[a][1].append(cbutton)
        return card

    generated_cards = []
    ltree, rtree, p = tan
    n = ltree[0]
    for j in range(1, n + 1):
        i = p[j - 1] # 'i' is defined here for card_finder_with_right_buttons
        subset_left = tuple(range(j-1)) + tuple(range(j,n))
        subset_right_unsorted = tuple(p[k]-1 for k in range(n) if k != j-1)
        sorted_subset_right = tuple(range(i-1)) + tuple(range(i,n))
        
        card_ltree = card_finder_with_left_buttons(ltree, subset_left, j)
        card_rtree = card_finder_with_right_buttons(rtree, sorted_subset_right, i, p.inverse())
        
        card_perm = perm_canonicalizer(subset_right_unsorted, i-1)
        
        raw_card = (card_ltree, card_rtree, press_buttons(card_perm, cbus[j]))
        generated_cards.append(raw_card)

    deck_representatives = []
    counts = []
    for card in generated_cards:
        found_isomorphic = False
        for i, rep in enumerate(deck_representatives):
            if is_isomorphic(card, rep):
                counts[i] += 1
                found_isomorphic = True
                break
        if not found_isomorphic:
            deck_representatives.append(card)
            counts.append(1)
            
    return list(zip(deck_representatives, counts))
    

def are_multidecks_equal(deck1, deck2):
    
    if len(deck1) != len(deck2):
        return False

    counts1 = sorted([count for rep, count in deck1])
    counts2 = sorted([count for rep, count in deck2])
    if counts1 != counts2:
        return False

    # The main matching logic
    unmatched_deck2_items = list(deck2)
    for rep1, count1 in deck1:
        found_match = False
        for i, (rep2, count2) in enumerate(unmatched_deck2_items):
            # Check for a match in count AND isomorphism
            if count1 == count2 and memoized_is_isomorphic(rep1, rep2):
                found_match = True
                # Remove the matched item from deck2's list so it can't be used again
                unmatched_deck2_items.pop(i)
                break # Move to the next item in deck1
        
        if not found_match:
            return False
            
    return True

#in: tanglegram tan
#out: A list of non-isomorphic representative cards in the deck.
def tan_deck(tan):
    multideck = tan_multideck(tan)
    deck_representatives = [rep for rep, count in multideck]
    return deck_representatives
    
def are_decks_equal(deck1, deck2):
    if len(deck1) != len(deck2):
        return False

    unmatched_deck2_cards = list(deck2)
    for card1 in deck1:
        found_match = False
        for i, card2 in enumerate(unmatched_deck2_cards):
            if memoized_is_isomorphic(card1, card2):
                found_match = True
                unmatched_deck2_cards.pop(i)
                break
        if not found_match:
            return False
    return True

list_culprit = [ ((4,0),(4,0), Permutation([1,4,3,2])),  ((4,1),(4,1), Permutation([1,3,2,4]))] 
def planar_check_4_5(tan):
    n = tan[0][0] 
    if n == 4: 
        for culprit in list_culprit:
            if is_isomorphic(culprit,tan):
                return True
        return False
    elif n == 5:
        deck = tan_deck(tan)
        for culprit in list_culprit:
            for el in deck:
                if is_isomorphic(el,culprit):
                    return True
        return False
    else:
        print("error")

#in: a tree = (n,s) 
#out: the tree (n+1,t) = (n,s) \oplus (1,0)
def add_one(T):
    return binary_tree(T,(1,0))

def generate_list_of_representatives(n):
    
    representatives = []
    k = W(n)
    
    for bl in range(k):
        for br in range(k):
            for perm in Permutations(n):
                tan = ((n, bl), (n, br), perm)
                is_new_class = True
                for rep in representatives:
                    if memoized_is_isomorphic(tan, rep):
                        is_new_class = False
                        break
                if is_new_class:
                    # We add the raw tanglegram itself, not a canonical form
                    representatives.append(tan)
                    
    return representatives

# Verify isomorphism test
# n = 5
# k = W(n)
# print("Generating list of non-isomorphic tanglegram representatives...")

for n in [5]:
    list_of_reps = generate_list_of_representatives(n)
    print(f"Found {len(list_of_reps)} unique tanglegram classes.")

    # print("Generating list of non-isomorphic tanglegram representatives for", n , "leaves")
    # list_of_reps = generate_list_of_representatives(n)
    # print(f"Found {len(list_of_reps)} unique tanglegram classes.")
    
    all_decks = [tan_deck(tan) for tan in list_of_reps]
    print("Finished pre-computing decks.")
    print("\nSearching for counterexamples...")
    
    Counterexamples = []
    
    for i in range(len(list_of_reps)):
        for j in range(i + 1, len(list_of_reps)):
            # Get the pre-computed decks
            deck_1 = all_decks[i]
            deck_2 = all_decks[j]
    
            # Use our new custom comparison function for DECKS
            if are_decks_equal(deck_1, deck_2):
                rep_1 = list_of_reps[i]
                rep_2 = list_of_reps[j]
                multi_deck_1 = tan_multideck(rep_1)
                multi_deck_2 = tan_multideck(rep_2)
    
                whether_multi_decks_equal = are_multidecks_equal(multi_deck_1, multi_deck_2)
                print("-----")
                print(rep_1, rep_2)
                # print(multi_deck_1,multi_deck_2)                
    
                non_planar_1 = planar_check_4_5(rep_1)
                non_planar_2 = planar_check_4_5(rep_2)
    
                if non_planar_1 or non_planar_2:
                    print("non_planar counterexample, ", rep_1, rep_2)
                else:
                    print("PLANAR")
    
                if rep_1[2].inverse() != rep_2[2]: 
                    print("NO SWITCHING")
                else:
                    print("switch left right trees")
                
                print("whether_multi_decks_equal", whether_multi_decks_equal)
    
                Counterexamples.append([rep_1, rep_2, whether_multi_decks_equal])
    
    print(f"\nFound {len(Counterexamples)} counterexample pairs in total.")
# Out:
# Found 114 unique tanglegram classes.
# Finished pre-computing decks.
#
# Searching for counterexamples...
# -----
# ((5, 0), (5, 0), [1, 3, 5, 2, 4]) ((5, 0), (5, 0), [1, 4, 2, 5, 3])
# PLANAR
# switch left right trees
# whether_multi_decks_equal False
# -----
# ((5, 0), (5, 0), [1, 5, 4, 3, 2]) ((5, 0), (5, 0), [3, 5, 4, 1, 2])
# non_planar counterexample,  ((5, 0), (5, 0), [1, 5, 4, 3, 2]) ((5, 0), (5, 0), [3, 5, 4, 1, 2])
# NO SWITCHING
# whether_multi_decks_equal False
# -----
# ((5, 0), (5, 0), [1, 5, 4, 3, 2]) ((5, 0), (5, 0), [4, 5, 1, 3, 2])
# non_planar counterexample,  ((5, 0), (5, 0), [1, 5, 4, 3, 2]) ((5, 0), (5, 0), [4, 5, 1, 3, 2])
# NO SWITCHING
# whether_multi_decks_equal False
# -----
# ((5, 0), (5, 0), [3, 5, 4, 1, 2]) ((5, 0), (5, 0), [4, 5, 1, 3, 2])
# non_planar counterexample,  ((5, 0), (5, 0), [3, 5, 4, 1, 2]) ((5, 0), (5, 0), [4, 5, 1, 3, 2])
# switch left right trees
# whether_multi_decks_equal True
# -----
# ...
